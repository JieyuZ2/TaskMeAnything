# %% [markdown]
# # Performing Threshold Query and Query Results Approximation in Task-Me-Anything
#
# In this notebook, we will demonstrate how to perform a “Threshold Query” in Task-Me-Anything. We’ll focus on identify the task plans with below 50% accuracy `llavav1.5-7b`  over 3200+ task plans on “2D sticker how many” task type. After that, we willl using `Fit` and `Active` query results approximation algorithms to approximate the performance of tasks plan within only 500 budgets.
#
#
#
#
#
#
#
#
#
#
#
#
# <!-- In this notebook we will illstrate how to conduct `Top K query` on multiple models in taskverse. Top K query has two types: Top K best query and Top K worst query, which aims to query the top k best or worst test cases.  We will use Top K worst query in this notebook. Top K worst query is to query the top k task categories that given `VQA model` performance at. (e.g GPT4v achieve 0.5 acc in task category 1 and 0.3 in task category 2, then task category 2 is worse than task category 1)
#
#
# In this notebook, we will first evaluates models on all the 2d sticker howmany test cases and got the top 10 worst performed cases as ground truth. Then we will use `Random Selection` and `Active Selection` method to approximate the top 10 worst performed cases. We will compare the performance of these two methods with the ground truth.
#
# In the `Random Selection` approach, we randomly select 2000 task categories and train the `performance regressor`. Conversely, in the second method, we iteratively select the top k worst-performing data points and train the `performance regressor` accordingly. We will discuss the details in later sections.
#
# It is important to note that the `Active Selection` of top k worst-performaing data is specifically tailored for identifying the top k worst scenarios. Since it is trained using data from the top k worst queries, it may not generalize well to scenarios involving the top k best queries or other requirements. In contrast, the `Random Selection` method offers a more generalized approach. -->

# %% [markdown]
# ## Generate tasks
#
# These are the process of task plans generation, illustrations on these part will be in the `generate` part of demo.
#
# In this step, we generate 3,249 “how many” task plans in 2D scenarios. Each task plan contains all the configuration and content needed to generate an image-question pair.

# %%
import sys
# set the working directory to the root of the project
sys.path.append("../..")
from tma.imageqa.sticker_2d import *
from tma.imageqa.metadata import Objaverse2DMetaData
from tma.task_store import TaskStore

# the code to download the source data, if you already downloaded the data, you can skip this step
# from huggingface_hub import snapshot_download
# path = "../taskverse-source"
# snapshot_download(repo_id="weikaih/taskverse-source", repo_type="dataset", local_dir=path)



path = '/your_path/TaskMeAnything-v1-source'
metadata = Objaverse2DMetaData('../../annotations', image_folder=f'{path}/object_images')
generator = HowManyGridTaskGenerator(metadata)


# enumerate all "how many" task plans
task_store = TaskStore(generator.schema)
generator.enumerate_task_plans(task_store)
df = task_store.return_df()


# sample a subset of the all "how many" task plans
interval = len(df) // 3000
df = df.iloc[::interval, :]
df
# Out:
# enumerating [how many attribute 1] task: 100%|██████████| 3/3 [00:00<00:00, 6868.40it/s]
# enumerating [how many attribute 2] task: 100%|██████████| 465/465 [00:01<00:00, 268.08it/s]
#       task type  grid number target category  count attribute type  \
# 0      how many            2            <NA>      1          color
# 10     how many            3            <NA>      7          color
# 20     how many            3            <NA>      4          color
# 30     how many            3            <NA>      1          color
# 40     how many            2            <NA>      2          color
# ...         ...          ...             ...    ...            ...
# 32440  how many            2          Q99895      4          color
# 32450  how many            3          Q99895      2          color
# 32460  how many            3          Q99895      4          color
# 32470  how many            3          Q99895      6          color
# 32480  how many            3          Q99895      8          color
#
#       attribute value
# 0                gold
# 10               gold
# 20                red
# 30              green
# 40              brown
# ...               ...
# 32440           white
# 32450           white
# 32460           white
# 32470           white
# 32480           white
#
# [3249 rows x 6 columns]

# %% [markdown]
# ## Embedding the tasks and create VQATaskEvaluator
#
#
# Task evaluator takes the model and the tasks as input, and evaluate and query the model's performance on the tasks generated by task plans.
#
#
#
# <!-- Because we want to fit a performance regressor, we need to embed the tasks. We will use the Cohere API to embed the tasks. First you need to set the `api_key` parameter to your Cohere API key. You can also using other embedding API or models to embed the tasks. (e.g Openai embedding API, BERT, etc.)
#
# Then you should create a `VQATaskEvaluator` object. `VQATaskEvaluator` is a class designed to evaluate a model's performance on task. It can handle the details in evaluate the model such as create the embedding of the tasks, fit the performance regressor, etc.
#
# Notice that `VQATaskEvaluator` can cache the embeddings to avoid redundant requests to the OpenAI API. You can change the path of the cache file by setting the `cache_path` parameter. -->

# %%
from tma.task_evaluator import VQATaskEvaluator

task_evaluator = VQATaskEvaluator(
    task_plan_df=df, # data frames task plans to evaluate
    task_generator=generator, # task generator, used to generate test instances for each task plan
    embedding_name='st',  # using sentence transformer (st) to embedding questions
    embedding_batch_size=10000,  # batch size for embedding
    n_instance_per_task=5,  # number of test instances generated per task plan
    n_trials_per_instance=3,  # number of trials per test instance
    cache_path_root=".cache",  # enter you path for cache
    seed=42  # random seed
)

# %% [markdown]
# ## Evaluating the model on all the task plans
#
# In this steps, we will start to get the ground truth of the query. We will not use query approximation algorithms in this step. Instead, we will evaluate the model on all the tasks and get the top 10 worst-performing tasks as the ground truth.

# %% [markdown]
# You can call tma.models.qa_model.list_vqa_models() to find all the available VQA models.

# %%
from tma.models.qa_model import list_imageqa_models

# list all available models
list_imageqa_models()
# Out:
# ['instructblip-flant5xl',
#  'instructblip-flant5xxl',
#  'instructblip-vicuna7b',
#  'instructblip-vicuna13b',
#  'blip2-flant5xxl',
#  'llavav1.5-7b',
#  'llavav1.5-13b',
#  'llavav1.6-34b',
#  'llava1.6-34b-api',
#  'qwenvl',
#  'qwenvl-chat',
#  'internvl-chat-v1.5',
#  'gpt4v',
#  'gpt4o',
#  'qwen-vl-plus',
#  'qwen-vl-max',
#  'gemini-vision-pro']

# %% [markdown]
# We will use `llavav1.5-7b` for showcasing, you can use other models you like or using multi-models.

# %%
from tma.models.qa_model import ImageQAModel
from tma.models.qa_model import prompt
import torch

# single model
model = ImageQAModel(model_name='llavav1.5-7b', precision=torch.bfloat16, prompt_name = "succinct_prompt", prompt_func=prompt.succinct_prompt, cache_path = ".cache/")

# # multiple models
# # Notice: If you have multiple GPUs, you can set the torch_device for each model to avoid running out of GPU memory.
# model1 = ImageQAModel(model_name='llavav1.5-7b', torch_device=0, precision=torch.bfloat16, prompt_name = "succinct_prompt", prompt_func=prompt.succinct_prompt, cache_path = ".cache/")
# model2 = ImageQAModel(model_name='qwenvl-chat', torch_device=1, precision=torch.bfloat16, prompt_name = "succinct_prompt", prompt_func=prompt.succinct_prompt, cache_path = ".cache/")
 
# model = [model1, model2]
# Out:
# [IMPORTANT] model cache is enabled, cache path: .cache/
# Loading llavav1.5-7b...
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Finish loading llavav1.5-7b

# %% [markdown]
# After loading model, we can start evaluating all the task plans.

# %%
import numpy as np

def results_process(ground_truth, groupby):
    indices = list(df.groupby(groupby).indices.items())
    return {k: np.mean(ground_truth[i]) for k, i in indices}

groupby = "target category"
ground_truth = np.array(task_evaluator.evaluate(model=model))

category_to_accuracy = results_process(ground_truth, groupby)
threshold_accuracy = 0.5 # set the threshold accuracy to 30% acc
# Out:
# Evaluating tasks: 100%|██████████| 3249/3249 [01:34<00:00, 34.53it/s]

# %%
def print_category_threshold_status(category_to_accuracy, threshold):
    total_categories = len(category_to_accuracy)
    below_threshold_count = sum(1 for acc in category_to_accuracy.values() if acc < threshold)
    proportion_below_threshold = below_threshold_count / total_categories
    print(f"Current Threshold: {threshold}")
    print(f"Total Categories: {total_categories}")
    print(f"Categories Below Threshold: {below_threshold_count}")
    print(f"Proportion Below Threshold: {proportion_below_threshold:.2f}")
    for category, accuracy in category_to_accuracy.items():
        status = "below" if accuracy < threshold else "above"
        print(f"Category: {category:<10} Accuracy: {accuracy:.2f} Status: {status}")
        
print_category_threshold_status(category_to_accuracy, threshold_accuracy)
# Out:
# Current Threshold: 0.5
# Total Categories: 465
# Categories Below Threshold: 390
# Proportion Below Threshold: 0.84
# Category: Q101674    Accuracy: 0.30 Status: below
# Category: Q1021686   Accuracy: 0.43 Status: below
# Category: Q102626    Accuracy: 0.37 Status: below
# Category: Q10289     Accuracy: 0.53 Status: above
# Category: Q104526    Accuracy: 0.28 Status: below
# Category: Q104555    Accuracy: 0.20 Status: below
# Category: Q104666136 Accuracy: 0.40 Status: below
# Category: Q1047832   Accuracy: 0.47 Status: below
# Category: Q106106    Accuracy: 0.37 Status: below
# Category: Q1064858   Accuracy: 0.48 Status: below
# Category: Q107126067 Accuracy: 0.44 Status: below
# Category: Q107196890 Accuracy: 0.55 Status: above
# Category: Q107293    Accuracy: 0.53 Status: above
# Category: Q107444    Accuracy: 0.25 Status: below
# Category: Q1093742   Accuracy: 0.57 Status: above
# Category: Q10990     Accuracy: 0.43 Status: below
# Category: Q11004     Accuracy: 0.56 Status: above
# Category: Q110079    Accuracy: 0.43 Status: below
# Category: Q11012     Accuracy: 0.46 Status: below
# Category: Q11019     Accuracy: 0.35 Status: below
# Category: Q11035     Accuracy: 0.30 Status: below
# Category: Q1127296   Accuracy: 0.50 Status: above
# Category: Q11285759  Accuracy: 0.28 Status: below
# Category: Q1129239   Accuracy: 0.30 Status: below
# Category: Q1136834   Accuracy: 0.44 Status: below
# Category: Q1138737   Accuracy: 0.48 Status: below
# Category: Q11404     Accuracy: 0.48 Status: below
# Category: Q11422     Accuracy: 0.23 Status: below
# Category: Q11435     Accuracy: 0.38 Status: below
# Category: Q11442     Accuracy: 0.37 Status: below
# Category: Q11460     Accuracy: 0.31 Status: below
# Category: Q1146001   Accuracy: 0.37 Status: below
# Category: Q11472     Accuracy: 0.36 Status: below
# Category: Q1151042   Accuracy: 0.43 Status: below
# Category: Q115435012 Accuracy: 0.40 Status: below
# Category: Q115618359 Accuracy: 0.36 Status: below
# Category: Q115921244 Accuracy: 0.40 Status: below
# Category: Q116221438 Accuracy: 0.33 Status: below
# Category: Q11629     Accuracy: 0.40 Status: below
# Category: Q11634     Accuracy: 0.56 Status: above
# Category: Q116434    Accuracy: 0.50 Status: below
# Category: Q116961643 Accuracy: 0.40 Status: below
# Category: Q116971226 Accuracy: 0.34 Status: below
# Category: Q117209093 Accuracy: 0.40 Status: below
# Category: Q11789812  Accuracy: 0.35 Status: below
# Category: Q11946202  Accuracy: 0.43 Status: below
# Category: Q119720106 Accuracy: 0.44 Status: below
# Category: Q1207302   Accuracy: 0.36 Status: below
# Category: Q1211272   Accuracy: 0.37 Status: below
# Category: Q121225283 Accuracy: 0.53 Status: above
# Category: Q12132     Accuracy: 0.30 Status: below
# Category: Q121916    Accuracy: 0.35 Status: below
# Category: Q122052040 Accuracy: 0.40 Status: below
# Category: Q12252328  Accuracy: 0.48 Status: below
# Category: Q122973887 Accuracy: 0.42 Status: below
# Category: Q123691907 Accuracy: 0.34 Status: below
# Category: Q124441    Accuracy: 0.52 Status: above
# Category: Q125356    Accuracy: 0.33 Status: below
# Category: Q127197    Accuracy: 0.37 Status: below
# Category: Q127666    Accuracy: 0.29 Status: below
# Category: Q127956    Accuracy: 0.51 Status: above
# Category: Q12888135  Accuracy: 0.50 Status: above
# Category: Q13049940  Accuracy: 0.43 Status: below
# Category: Q13099586  Accuracy: 0.53 Status: above
# Category: Q1310214   Accuracy: 0.35 Status: below
# Category: Q131207    Accuracy: 0.48 Status: below
# Category: Q131419    Accuracy: 0.47 Status: below
# Category: Q131514    Accuracy: 0.34 Status: below
# Category: Q131647    Accuracy: 0.34 Status: below
# Category: Q131696    Accuracy: 0.29 Status: below
# Category: Q131704    Accuracy: 0.43 Status: below
# Category: Q131740    Accuracy: 0.39 Status: below
# Category: Q131746    Accuracy: 0.44 Status: below
# Category: Q1317634   Accuracy: 0.23 Status: below
# Category: Q13191     Accuracy: 0.47 Status: below
# Category: Q13202263  Accuracy: 0.10 Status: below
# Category: Q132041    Accuracy: 0.44 Status: below
# Category: Q1320546   Accuracy: 0.47 Status: below
# Category: Q13233     Accuracy: 0.44 Status: below
# Category: Q1323314   Accuracy: 0.36 Status: below
# Category: Q132397    Accuracy: 0.41 Status: below
# Category: Q13266     Accuracy: 0.39 Status: below
# Category: Q13276     Accuracy: 0.49 Status: below
# Category: Q13317     Accuracy: 0.49 Status: below
# Category: Q1333024   Accuracy: 0.38 Status: below
# Category: Q13360264  Accuracy: 0.53 Status: above
# Category: Q133792    Accuracy: 0.50 Status: above
# Category: Q134205    Accuracy: 0.31 Status: below
# Category: Q13422881  Accuracy: 0.43 Status: below
# Category: Q134560    Accuracy: 0.45 Status: below
# Category: Q134566    Accuracy: 0.40 Status: below
# Category: Q1347864   Accuracy: 0.49 Status: below
# Category: Q13479587  Accuracy: 0.44 Status: below
# Category: Q1349717   Accuracy: 0.45 Status: below
# Category: Q1355359   Accuracy: 0.42 Status: below
# Category: Q1357      Accuracy: 0.43 Status: below
# Category: Q1361086   Accuracy: 0.44 Status: below
# Category: Q1368      Accuracy: 0.46 Status: below
# Category: Q13681     Accuracy: 0.29 Status: below
# Category: Q1384616   Accuracy: 0.36 Status: below
# Category: Q1390      Accuracy: 0.49 Status: below
# Category: Q140565    Accuracy: 0.43 Status: below
# Category: Q1419626   Accuracy: 0.59 Status: above
# Category: Q1427887   Accuracy: 0.40 Status: below
# Category: Q14524031  Accuracy: 0.45 Status: below
# Category: Q14560     Accuracy: 0.51 Status: above
# Category: Q1460219   Accuracy: 0.47 Status: below
# Category: Q14660     Accuracy: 0.33 Status: below
# Category: Q14674     Accuracy: 0.37 Status: below
# Category: Q14745     Accuracy: 0.32 Status: below
# Category: Q14748     Accuracy: 0.43 Status: below
# Category: Q147538    Accuracy: 0.39 Status: below
# Category: Q148493    Accuracy: 0.47 Status: below
# Category: Q14890     Accuracy: 0.45 Status: below
# Category: Q148958    Accuracy: 0.43 Status: below
# Category: Q14952     Accuracy: 0.42 Status: below
# Category: Q14963     Accuracy: 0.40 Status: below
# Category: Q149757    Accuracy: 0.46 Status: below
# Category: Q1501161   Accuracy: 0.42 Status: below
# Category: Q1501968   Accuracy: 0.40 Status: below
# Category: Q15026     Accuracy: 0.48 Status: below
# Category: Q1507442   Accuracy: 0.43 Status: below
# Category: Q1514280   Accuracy: 0.53 Status: above
# Category: Q15148     Accuracy: 0.48 Status: below
# Category: Q152       Accuracy: 0.43 Status: below
# Category: Q152095    Accuracy: 0.45 Status: below
# Category: Q152574    Accuracy: 0.37 Status: below
# Category: Q1531435   Accuracy: 0.53 Status: above
# Category: Q15328     Accuracy: 0.41 Status: below
# Category: Q153988    Accuracy: 0.37 Status: below
# Category: Q154       Accuracy: 0.31 Status: below
# Category: Q154411    Accuracy: 0.39 Status: below
# Category: Q1548030   Accuracy: 0.48 Status: below
# Category: Q155972    Accuracy: 0.27 Status: below
# Category: Q1572702   Accuracy: 0.48 Status: below
# Category: Q1578      Accuracy: 0.47 Status: below
# Category: Q159391    Accuracy: 0.45 Status: below
# Category: Q161071    Accuracy: 0.45 Status: below
# Category: Q161439    Accuracy: 0.07 Status: below
# Category: Q161524    Accuracy: 0.50 Status: above
# Category: Q161928    Accuracy: 0.34 Status: below
# Category: Q1622390   Accuracy: 0.40 Status: below
# Category: Q1629107   Accuracy: 0.31 Status: below
# Category: Q16338     Accuracy: 0.67 Status: above
# Category: Q165199    Accuracy: 0.36 Status: below
# Category: Q165308    Accuracy: 0.56 Status: above
# Category: Q165447    Accuracy: 0.40 Status: below
# Category: Q16629185  Accuracy: 0.45 Status: below
# Category: Q1666865   Accuracy: 0.42 Status: below
# Category: Q16836622  Accuracy: 0.31 Status: below
# Category: Q168639    Accuracy: 0.53 Status: above
# Category: Q16868432  Accuracy: 0.46 Status: below
# Category: Q169031    Accuracy: 0.52 Status: above
# Category: Q16917685  Accuracy: 0.25 Status: below
# Category: Q170124    Accuracy: 0.46 Status: below
# Category: Q170285    Accuracy: 0.47 Status: below
# Category: Q170484    Accuracy: 0.28 Status: below
# Category: Q170486    Accuracy: 0.40 Status: below
# Category: Q170984    Accuracy: 0.41 Status: below
# Category: Q17119302  Accuracy: 0.44 Status: below
# Category: Q171446    Accuracy: 0.29 Status: below
# Category: Q171495    Accuracy: 0.31 Status: below
# Category: Q172833    Accuracy: 0.20 Status: below
# Category: Q173517    Accuracy: 0.45 Status: below
# Category: Q173603    Accuracy: 0.50 Status: below
# Category: Q173725    Accuracy: 0.43 Status: below
# Category: Q1744391   Accuracy: 0.46 Status: below
# Category: Q17489160  Accuracy: 0.40 Status: below
# Category: Q17517     Accuracy: 0.37 Status: below
# Category: Q1751850   Accuracy: 0.38 Status: below
# Category: Q1756633   Accuracy: 0.42 Status: below
# Category: Q1760958   Accuracy: 0.37 Status: below
# Category: Q1762457   Accuracy: 0.51 Status: above
# Category: Q177       Accuracy: 0.56 Status: above
# Category: Q178       Accuracy: 0.23 Status: below
# Category: Q1780509   Accuracy: 0.42 Status: below
# Category: Q178794    Accuracy: 0.37 Status: below
# Category: Q1798603   Accuracy: 0.29 Status: below
# Category: Q179904    Accuracy: 0.29 Status: below
# Category: Q181055    Accuracy: 0.53 Status: above
# Category: Q1820120   Accuracy: 0.48 Status: below
# Category: Q182780    Accuracy: 0.39 Status: below
# Category: Q182940    Accuracy: 0.35 Status: below
# Category: Q185091    Accuracy: 0.59 Status: above
# Category: Q185217    Accuracy: 0.42 Status: below
# Category: Q18545     Accuracy: 0.43 Status: below
# Category: Q185583    Accuracy: 0.38 Status: below
# Category: Q185785    Accuracy: 0.34 Status: below
# Category: Q186819    Accuracy: 0.38 Status: below
# Category: Q18696213  Accuracy: 0.55 Status: above
# Category: Q188075    Accuracy: 0.29 Status: below
# Category: Q189299    Accuracy: 0.27 Status: below
# Category: Q190672    Accuracy: 0.52 Status: above
# Category: Q190868    Accuracy: 0.42 Status: below
# Category: Q191022    Accuracy: 0.45 Status: below
# Category: Q191768    Accuracy: 0.35 Status: below
# Category: Q191851    Accuracy: 0.28 Status: below
# Category: Q191931    Accuracy: 0.55 Status: above
# Category: Q192234    Accuracy: 0.41 Status: below
# Category: Q192783    Accuracy: 0.51 Status: above
# Category: Q1929383   Accuracy: 0.43 Status: below
# Category: Q193897    Accuracy: 0.42 Status: below
# Category: Q193955    Accuracy: 0.39 Status: below
# Category: Q196538    Accuracy: 0.29 Status: below
# Category: Q19827042  Accuracy: 0.28 Status: below
# Category: Q19968163  Accuracy: 0.29 Status: below
# Category: Q2000617   Accuracy: 0.43 Status: below
# Category: Q200539    Accuracy: 0.32 Status: below
# Category: Q200814    Accuracy: 0.40 Status: below
# Category: Q2009740   Accuracy: 0.54 Status: above
# Category: Q201097    Accuracy: 0.51 Status: above
# Category: Q20134     Accuracy: 0.38 Status: below
# Category: Q201664    Accuracy: 0.35 Status: below
# Category: Q2024731   Accuracy: 0.46 Status: below
# Category: Q20459     Accuracy: 0.40 Status: below
# Category: Q204776    Accuracy: 0.44 Status: below
# Category: Q20638126  Accuracy: 0.55 Status: above
# Category: Q207220    Accuracy: 0.07 Status: below
# Category: Q207763    Accuracy: 0.27 Status: below
# Category: Q208440    Accuracy: 0.41 Status: below
# Category: Q2095      Accuracy: 0.38 Status: below
# Category: Q210723    Accuracy: 0.42 Status: below
# Category: Q21167379  Accuracy: 0.48 Status: below
# Category: Q211841    Accuracy: 0.33 Status: below
# Category: Q212758    Accuracy: 0.35 Status: below
# Category: Q212920    Accuracy: 0.37 Status: below
# Category: Q213062    Accuracy: 0.55 Status: above
# Category: Q213096    Accuracy: 0.40 Status: below
# Category: Q213477    Accuracy: 0.32 Status: below
# Category: Q213777    Accuracy: 0.48 Status: below
# Category: Q2142903   Accuracy: 0.41 Status: below
# Category: Q214488    Accuracy: 0.36 Status: below
# Category: Q214649    Accuracy: 0.38 Status: below
# Category: Q215857    Accuracy: 0.39 Status: below
# Category: Q2160801   Accuracy: 0.35 Status: below
# Category: Q216530    Accuracy: 0.46 Status: below
# Category: Q217446    Accuracy: 0.47 Status: below
# Category: Q217541    Accuracy: 0.43 Status: below
# Category: Q2207370   Accuracy: 0.47 Status: below
# Category: Q221994    Accuracy: 0.53 Status: above
# Category: Q222405    Accuracy: 0.43 Status: below
# Category: Q223269    Accuracy: 0.38 Status: below
# Category: Q223575    Accuracy: 0.50 Status: above
# Category: Q2248059   Accuracy: 0.25 Status: below
# Category: Q22676     Accuracy: 0.37 Status: below
# Category: Q22710     Accuracy: 0.37 Status: below
# Category: Q232191    Accuracy: 0.49 Status: below
# Category: Q232254    Accuracy: 0.45 Status: below
# Category: Q233040    Accuracy: 0.43 Status: below
# Category: Q234668    Accuracy: 0.50 Status: above
# Category: Q234870    Accuracy: 0.33 Status: below
# Category: Q23490     Accuracy: 0.41 Status: below
# Category: Q235041    Accuracy: 0.57 Status: above
# Category: Q23504115  Accuracy: 0.37 Status: below
# Category: Q235783    Accuracy: 0.50 Status: above
# Category: Q23664     Accuracy: 0.27 Status: below
# Category: Q2366864   Accuracy: 0.42 Status: below
# Category: Q2383811   Accuracy: 0.32 Status: below
# Category: Q2397485   Accuracy: 0.49 Status: below
# Category: Q2425052   Accuracy: 0.44 Status: below
# Category: Q2426768   Accuracy: 0.47 Status: below
# Category: Q2447985   Accuracy: 0.37 Status: below
# Category: Q245005    Accuracy: 0.40 Status: below
# Category: Q2453629   Accuracy: 0.45 Status: below
# Category: Q245761    Accuracy: 0.20 Status: below
# Category: Q250       Accuracy: 0.45 Status: below
# Category: Q2524539   Accuracy: 0.32 Status: below
# Category: Q25294     Accuracy: 0.93 Status: above
# Category: Q25403900  Accuracy: 0.34 Status: below
# Category: Q2574750   Accuracy: 0.39 Status: below
# Category: Q2596997   Accuracy: 0.18 Status: below
# Category: Q2623418   Accuracy: 0.43 Status: below
# Category: Q2637814   Accuracy: 0.28 Status: below
# Category: Q265868    Accuracy: 0.40 Status: below
# Category: Q26972858  Accuracy: 0.36 Status: below
# Category: Q26988406  Accuracy: 0.36 Status: below
# Category: Q26995321  Accuracy: 0.32 Status: below
# Category: Q27149326  Accuracy: 0.33 Status: below
# Category: Q2715770   Accuracy: 0.40 Status: below
# Category: Q272502    Accuracy: 0.44 Status: below
# Category: Q273318    Accuracy: 0.49 Status: below
# Category: Q2741056   Accuracy: 0.42 Status: below
# Category: Q2750929   Accuracy: 0.22 Status: below
# Category: Q28692583  Accuracy: 0.52 Status: above
# Category: Q28803     Accuracy: 0.40 Status: below
# Category: Q28932195  Accuracy: 0.39 Status: below
# Category: Q29024343  Accuracy: 0.27 Status: below
# Category: Q2920313   Accuracy: 0.33 Status: below
# Category: Q3033123   Accuracy: 0.41 Status: below
# Category: Q3057632   Accuracy: 0.47 Status: below
# Category: Q3067542   Accuracy: 0.77 Status: above
# Category: Q31087     Accuracy: 0.44 Status: below
# Category: Q311666    Accuracy: 0.37 Status: below
# Category: Q3246832   Accuracy: 0.54 Status: above
# Category: Q32489     Accuracy: 0.41 Status: below
# Category: Q327954    Accuracy: 0.49 Status: below
# Category: Q3314483   Accuracy: 0.46 Status: below
# Category: Q33163     Accuracy: 0.49 Status: below
# Category: Q34379     Accuracy: 0.33 Status: below
# Category: Q34687     Accuracy: 0.87 Status: above
# Category: Q34735     Accuracy: 0.42 Status: below
# Category: Q3506176   Accuracy: 0.29 Status: below
# Category: Q35197     Accuracy: 0.24 Status: below
# Category: Q35473     Accuracy: 0.44 Status: below
# Category: Q36539     Accuracy: 0.34 Status: below
# Category: Q36641511  Accuracy: 0.52 Status: above
# Category: Q36794     Accuracy: 0.41 Status: below
# Category: Q37152     Accuracy: 0.48 Status: below
# Category: Q3736439   Accuracy: 0.63 Status: above
# Category: Q37501     Accuracy: 0.48 Status: below
# Category: Q376       Accuracy: 0.38 Status: below
# Category: Q3773693   Accuracy: 0.32 Status: below
# Category: Q37828     Accuracy: 0.24 Status: below
# Category: Q381165    Accuracy: 0.49 Status: below
# Category: Q386215    Accuracy: 0.43 Status: below
# Category: Q38645     Accuracy: 0.39 Status: below
# Category: Q39397     Accuracy: 0.60 Status: above
# Category: Q39546     Accuracy: 0.32 Status: below
# Category: Q3962      Accuracy: 0.27 Status: below
# Category: Q3966      Accuracy: 0.39 Status: below
# Category: Q39908     Accuracy: 0.40 Status: below
# Category: Q40050     Accuracy: 0.37 Status: below
# Category: Q4006      Accuracy: 0.30 Status: below
# Category: Q40614     Accuracy: 0.53 Status: above
# Category: Q40847     Accuracy: 0.45 Status: below
# Category: Q41207     Accuracy: 0.52 Status: above
# Category: Q41274     Accuracy: 0.53 Status: above
# Category: Q412770    Accuracy: 0.49 Status: below
# Category: Q41298     Accuracy: 0.48 Status: below
# Category: Q41607     Accuracy: 0.35 Status: below
# Category: Q4213      Accuracy: 0.43 Status: below
# Category: Q42177     Accuracy: 0.31 Status: below
# Category: Q42378     Accuracy: 0.39 Status: below
# Category: Q42527     Accuracy: 0.22 Status: below
# Category: Q42622779  Accuracy: 0.41 Status: below
# Category: Q42889     Accuracy: 0.43 Status: below
# Category: Q43013     Accuracy: 0.42 Status: below
# Category: Q43533     Accuracy: 0.37 Status: below
# Category: Q43663     Accuracy: 0.52 Status: above
# Category: Q4388799   Accuracy: 0.39 Status: below
# Category: Q44106     Accuracy: 0.30 Status: below
# Category: Q4439      Accuracy: 0.58 Status: above
# Category: Q446       Accuracy: 0.41 Status: below
# Category: Q4498085   Accuracy: 0.41 Status: below
# Category: Q45922     Accuracy: 0.51 Status: above
# Category: Q46335     Accuracy: 0.33 Status: below
# Category: Q46384     Accuracy: 0.44 Status: below
# Category: Q465453    Accuracy: 0.47 Status: below
# Category: Q467505    Accuracy: 0.32 Status: below
# Category: Q46847     Accuracy: 0.39 Status: below
# Category: Q47107     Accuracy: 0.42 Status: below
# Category: Q471898    Accuracy: 0.37 Status: below
# Category: Q47722     Accuracy: 0.40 Status: below
# Category: Q477248    Accuracy: 0.46 Status: below
# Category: Q483634    Accuracy: 0.40 Status: below
# Category: Q4858753   Accuracy: 0.35 Status: below
# Category: Q49013     Accuracy: 0.42 Status: below
# Category: Q501862    Accuracy: 0.30 Status: below
# Category: Q503       Accuracy: 0.56 Status: above
# Category: Q506       Accuracy: 0.48 Status: below
# Category: Q50643     Accuracy: 0.28 Status: below
# Category: Q5082128   Accuracy: 0.39 Status: below
# Category: Q510176    Accuracy: 0.43 Status: below
# Category: Q5113      Accuracy: 0.30 Status: below
# Category: Q51338     Accuracy: 0.44 Status: below
# Category: Q5159627   Accuracy: 0.46 Status: below
# Category: Q5290      Accuracy: 0.35 Status: below
# Category: Q5318      Accuracy: 0.47 Status: below
# Category: Q536135    Accuracy: 0.33 Status: below
# Category: Q55417699  Accuracy: 0.47 Status: below
# Category: Q5581528   Accuracy: 0.37 Status: below
# Category: Q56139     Accuracy: 0.52 Status: above
# Category: Q5689512   Accuracy: 0.46 Status: below
# Category: Q570       Accuracy: 0.56 Status: above
# Category: Q571       Accuracy: 0.45 Status: below
# Category: Q57216     Accuracy: 0.38 Status: below
# Category: Q57583712  Accuracy: 0.45 Status: below
# Category: Q581105    Accuracy: 0.35 Status: below
# Category: Q5843      Accuracy: 0.49 Status: below
# Category: Q5881191   Accuracy: 0.51 Status: above
# Category: Q58964     Accuracy: 0.49 Status: below
# Category: Q5936788   Accuracy: 0.28 Status: below
# Category: Q5953359   Accuracy: 0.49 Status: below
# Category: Q5994      Accuracy: 0.31 Status: below
# Category: Q599797    Accuracy: 0.60 Status: above
# Category: Q60142     Accuracy: 0.43 Status: below
# Category: Q60310748  Accuracy: 0.36 Status: below
# Category: Q605384    Accuracy: 0.38 Status: below
# Category: Q613972    Accuracy: 0.37 Status: below
# Category: Q614467    Accuracy: 0.53 Status: above
# Category: Q6147804   Accuracy: 0.48 Status: below
# Category: Q617239    Accuracy: 0.42 Status: below
# Category: Q63917312  Accuracy: 0.47 Status: below
# Category: Q645292    Accuracy: 0.38 Status: below
# Category: Q6498398   Accuracy: 0.38 Status: below
# Category: Q65284752  Accuracy: 0.40 Status: below
# Category: Q656656    Accuracy: 0.46 Status: below
# Category: Q659495    Accuracy: 0.37 Status: below
# Category: Q6607      Accuracy: 0.48 Status: below
# Category: Q666242    Accuracy: 0.55 Status: above
# Category: Q68        Accuracy: 0.52 Status: above
# Category: Q6817227   Accuracy: 0.50 Status: below
# Category: Q682582    Accuracy: 0.23 Status: below
# Category: Q6887300   Accuracy: 0.49 Status: below
# Category: Q6950796   Accuracy: 0.31 Status: below
# Category: Q7220961   Accuracy: 0.10 Status: below
# Category: Q72797     Accuracy: 0.52 Status: above
# Category: Q728       Accuracy: 0.36 Status: below
# Category: Q729       Accuracy: 0.30 Status: below
# Category: Q73498530  Accuracy: 0.38 Status: below
# Category: Q74048276  Accuracy: 0.33 Status: below
# Category: Q744112    Accuracy: 0.33 Status: below
# Category: Q749316    Accuracy: 0.43 Status: below
# Category: Q755313    Accuracy: 0.37 Status: below
# Category: Q756       Accuracy: 0.51 Status: above
# Category: Q758891    Accuracy: 0.44 Status: below
# Category: Q768186    Accuracy: 0.27 Status: below
# Category: Q7802      Accuracy: 0.41 Status: below
# Category: Q7927908   Accuracy: 0.47 Status: below
# Category: Q7987      Accuracy: 0.48 Status: below
# Category: Q80151     Accuracy: 0.44 Status: below
# Category: Q80228     Accuracy: 0.45 Status: below
# Category: Q8026408   Accuracy: 0.55 Status: above
# Category: Q8075      Accuracy: 0.38 Status: below
# Category: Q8076      Accuracy: 0.36 Status: below
# Category: Q809910    Accuracy: 0.49 Status: below
# Category: Q815738    Accuracy: 0.39 Status: below
# Category: Q81727     Accuracy: 0.50 Status: below
# Category: Q81881     Accuracy: 0.31 Status: below
# Category: Q81895     Accuracy: 0.53 Status: above
# Category: Q81944     Accuracy: 0.44 Status: below
# Category: Q82        Accuracy: 0.80 Status: above
# Category: Q821952    Accuracy: 0.48 Status: below
# Category: Q8355      Accuracy: 0.40 Status: below
# Category: Q838948    Accuracy: 0.39 Status: below
# Category: Q8492      Accuracy: 0.36 Status: below
# Category: Q8495      Accuracy: 0.48 Status: below
# Category: Q849813    Accuracy: 0.17 Status: below
# Category: Q849964    Accuracy: 0.35 Status: below
# Category: Q853185    Accuracy: 0.33 Status: below
# Category: Q855373    Accuracy: 0.38 Status: below
# Category: Q859281    Accuracy: 0.32 Status: below
# Category: Q860861    Accuracy: 0.33 Status: below
# Category: Q862454    Accuracy: 0.33 Status: below
# Category: Q864114    Accuracy: 0.33 Status: below
# Category: Q865054    Accuracy: 0.37 Status: below
# Category: Q865422    Accuracy: 0.52 Status: above
# Category: Q866153    Accuracy: 0.36 Status: below
# Category: Q867246    Accuracy: 0.53 Status: above
# Category: Q869381    Accuracy: 0.33 Status: below
# Category: Q875696    Accuracy: 0.21 Status: below
# Category: Q89        Accuracy: 0.44 Status: below
# Category: Q927924    Accuracy: 0.67 Status: above
# Category: Q93189     Accuracy: 0.52 Status: above
# Category: Q938319    Accuracy: 0.41 Status: below
# Category: Q939611    Accuracy: 0.30 Status: below
# Category: Q941818    Accuracy: 0.53 Status: above
# Category: Q947211    Accuracy: 0.58 Status: above
# Category: Q951964    Accuracy: 0.38 Status: below
# Category: Q954087    Accuracy: 0.65 Status: above
# Category: Q958210    Accuracy: 0.36 Status: below
# Category: Q961769    Accuracy: 0.64 Status: above
# Category: Q96952903  Accuracy: 0.42 Status: below
# Category: Q987767    Accuracy: 0.47 Status: below
# Category: Q99895     Accuracy: 0.36 Status: below

# %% [markdown]
# # Apply query approximation algorithms
# Query approximation algorithms means only evaluate model on a subset of tasks and use the result to approximate the performance on the whole task plans.
#
# We will use the `Fit` algorithm and `Active` algorithm to approximate the top k worst query, and compare the performance of these two methods with the ground truth. For each algorithm, we will give 500 budgets, which means the approximation algorithm can only evaluate 500 task plans.
#
# * In the `Fit` approach, we randomly select 500 task plans and fit the function approximator.
# * In the `Active` approach, we start with 200 task plans and then gradually add more task plans (10 each steps) to the training set based on the function approximator's predictions.

# %%
# here are the functions to evaluate the approximation results with the ground truth
from sklearn.metrics import accuracy_score, precision_score, f1_score

def calculate_metrics(gt_labels, pred_labels):
    accuracy = accuracy_score(gt_labels, pred_labels)
    precision = precision_score(gt_labels, pred_labels)
    f1 = f1_score(gt_labels, pred_labels)
    return accuracy, precision, f1

def print_results(actual_categories_above_threshold, approximate_categories_above_threshold):
    gt_labels = [1 if cat in actual_categories_above_threshold else 0 for cat in approximate_categories_above_threshold]
    pred_labels = [1] * len(approximate_categories_above_threshold)  # All are predicted as 1
    accuracy, precision, f1 = calculate_metrics(gt_labels, pred_labels)
    print("Overall Metrics:")
    print(f"  Accuracy : {accuracy:.2f}")
    print(f"  Precision: {precision:.2f}")
    print(f"  F1 Score : {f1:.2f}")

# %% [markdown]
# ### Use "Fit" approximation algorithm

# %%
# set up the budget    
budget = 500
np.random.seed(42)
perm = np.random.permutation(len(df))
x_indices = perm[:budget]

# it return all the that > 50% accuracy
subset_approximation_results, performance_regressor = task_evaluator.threshold_query(
    threshold=threshold_accuracy,
    x_indices=x_indices,
    model=model,
    by=groupby,
    greater_than=False,
    fit_function_approximator=True
)
subset_approximation_categories_above_threshold = [result[0]for result in subset_approximation_results]
ground_truth_categories_above_threshold = [category for category in category_to_accuracy if category_to_accuracy[category] >= threshold_accuracy]
print_results(ground_truth_categories_above_threshold, subset_approximation_categories_above_threshold)
# Out:
# Evaluating tasks: 100%|██████████| 500/500 [00:01<00:00, 485.13it/s]
# Embedding tasks: 100%|██████████| 3249/3249 [00:01<00:00, 1785.72it/s]
# Overall Metrics:
#   Accuracy : 0.15
#   Precision: 0.15
#   F1 Score : 0.26

# %% [markdown]
# ### Use "Active" approximation algorithm

# %%
warmup_budget=200
active_approximation_results, performance_regressor = task_evaluator.active_threshold_query(
    threshold=threshold_accuracy,
    warmup_budget=warmup_budget,
    model=model,
    by=groupby,
    budget=budget - warmup_budget,
    greater_than=False,
)
active_approximation_categories_above_threshold = [result[0]for result in active_approximation_results]
print_results(ground_truth_categories_above_threshold, active_approximation_categories_above_threshold)
# Out:
# [WARMUP] Querying 200 tasks
# Evaluating tasks: 100%|██████████| 200/200 [00:00<00:00, 512.75it/s]
# [Query] Queried 300/300 tasks
# Overall Metrics:
#   Accuracy : 0.13
#   Precision: 0.13
#   F1 Score : 0.23
